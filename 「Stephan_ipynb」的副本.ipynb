# %% [markdown]
# <a href="https://colab.research.google.com/github/t0mst0ne/earthquake/blob/main/%E3%80%8CStephan_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from xgboost import XGBClassifier
import graphviz
from sklearn.metrics  import precision_score, accuracy_score, confusion_matrix, f1_score, mean_squared_error
import matplotlib.pyplot as plt
import time

# %%
df = pd.read_csv("output2.csv")

# %%
import numpy as np

# 將 DataFrame 轉換為 NumPy 數組
tec_array = df['TEC'].values
dst_array = df['Dst'].values
mag_array = df['mag'].values

# 使用 NumPy 來構建 X 和 Y
X, Y = [], []
window_size = 1440
#for i in range(0, len(tec_array) - window_size):
for i in range(0, len(tec_array) - window_size):
    # 使用切片操作來構建 X
    tec_slice = tec_array[i:i + window_size]
    dst_slice = dst_array[i:i + window_size]
    X.append(np.concatenate([tec_slice, dst_slice]))

    # 構建 Y
    if mag_array[i + window_size] >= 5:
        Y.append(1)
    else:
        Y.append(0)

# 轉換 X 和 Y 為 NumPy 數組
X = np.array(X)
Y = np.array(Y)

# 打印信息
print(X[0])
print(X.shape)
# Out:
# [22.71 23.45 24.22 ...  0.    0.    0.  ]
# (384907, 2880)

# %%
# 保存到 CSV 文件

# 假設 X 和 Y 已經是 NumPy 數組
# 首先將 X 轉換為 DataFrame
X_df = pd.DataFrame(X)

# 將 Y 轉換為 DataFrame
Y_df = pd.DataFrame(Y, columns=['label'])

# 合併 X 和 Y
combined_df = pd.concat([X_df, Y_df], axis=1)

# 保存到 CSV 文件
combined_df.to_csv('data_1440_>0.csv', index=False)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
print(X_train.shape)
import xgboost as xgb
num_neg = sum(Y_train == 0)
num_pos = sum(Y_train == 1)
scale_pos_weight = num_neg / num_pos
print("scale_pos_weight",scale_pos_weight)
# 創建DMatrix
dtrain = xgb.DMatrix(X_train, label=Y_train)
dtest = xgb.DMatrix(X_test, label=Y_test)
# Out:
# (269434, 2880)
# scale_pos_weight 937.794425087108

# %%
# 指定參數
params = {
    'max_depth': 3,  # 決定樹的深度
    'eta': 0.3,      # 學習率
    'objective': 'binary:logistic',
    'eval_metric': 'logloss' , # logloss作為評估指標,
#    'eval_metric': 'auc' , # auc 作為評估指標,
    'scale_pos_weight': scale_pos_weight ,
}

num_round = 100  # 訓練迭代的次數
early_stopping_rounds=50
eval_set = [(dtrain, 'train'), (dtest, 'eval')]

# 訓練模型
start = time.time()
evals_result = {}
bst = xgb.train(params, dtrain, num_round, evals=eval_set, early_stopping_rounds=early_stopping_rounds,evals_result=evals_result)
end = time.time()
print("訓練時間:", end - start)

#import xgboost as xgb
#import matplotlib.pyplot as plt


# 訓練和測試誤差曲線的繪製
train_error = evals_result['train']['logloss']  # 換成您的評估指標 logloss or auc
test_error = evals_result['eval']['logloss']  # 換成您的評估指標
epochs = len(train_error)
x_axis = range(0, epochs)

# 繪圖
plt.figure(figsize=(12,6))
plt.plot(x_axis, train_error, label='Train')
plt.plot(x_axis, test_error, label='Test')
plt.legend()

plt.ylabel('Error')
plt.xlabel('Number of iterations')
plt.title('XGBoost Train/Test Error over Iterations [logloss]')
plt.show()


plt.figure(figsize=(100, 80))  # 這裡10是寬度, 8是高度, 單位是英寸
#xgb.plot_importance(bst)
xgb.plot_importance(bst, importance_type='weight', max_num_features=30, height=0.5)
plt.rcParams['font.size'] = 8
plt.show()  # 顯示圖形
plt.savefig('feature_importance.jpg', format='jpg', dpi=300, bbox_inches='tight')
plt.close()  # 關閉圖形，避免再次顯示


xgb.to_graphviz(bst)
# Out:
# [0]	train-logloss:0.67178	eval-logloss:0.67167
# [1]	train-logloss:0.65557	eval-logloss:0.65582
# [2]	train-logloss:0.64504	eval-logloss:0.64543
# [3]	train-logloss:0.62706	eval-logloss:0.62716
# [4]	train-logloss:0.60758	eval-logloss:0.60798
# [5]	train-logloss:0.59588	eval-logloss:0.59610
# [6]	train-logloss:0.58955	eval-logloss:0.58978
# [7]	train-logloss:0.57900	eval-logloss:0.57915
# [8]	train-logloss:0.57222	eval-logloss:0.57212
# [9]	train-logloss:0.55688	eval-logloss:0.55711
# [10]	train-logloss:0.55219	eval-logloss:0.55290
# [11]	train-logloss:0.54254	eval-logloss:0.54337
# [12]	train-logloss:0.53391	eval-logloss:0.53465
# [13]	train-logloss:0.53011	eval-logloss:0.53087
# [14]	train-logloss:0.52413	eval-logloss:0.52475
# [15]	train-logloss:0.51684	eval-logloss:0.51726
# [16]	train-logloss:0.51036	eval-logloss:0.51106
# [17]	train-logloss:0.49982	eval-logloss:0.50057
# [18]	train-logloss:0.48899	eval-logloss:0.49054
# [19]	train-logloss:0.48273	eval-logloss:0.48434
# [20]	train-logloss:0.47572	eval-logloss:0.47708
# [21]	train-logloss:0.46892	eval-logloss:0.47039
# [22]	train-logloss:0.46435	eval-logloss:0.46591
# [23]	train-logloss:0.46123	eval-logloss:0.46274
# [24]	train-logloss:0.45625	eval-logloss:0.45764
# [25]	train-logloss:0.44991	eval-logloss:0.45139
# [26]	train-logloss:0.43744	eval-logloss:0.43933
# [27]	train-logloss:0.42797	eval-logloss:0.42996
# [28]	train-logloss:0.42105	eval-logloss:0.42279
# [29]	train-logloss:0.41472	eval-logloss:0.41634
# [30]	train-logloss:0.40999	eval-logloss:0.41172
# [31]	train-logloss:0.40009	eval-logloss:0.40183
# [32]	train-logloss:0.39442	eval-logloss:0.39606
# [33]	train-logloss:0.38984	eval-logloss:0.39161
# [34]	train-logloss:0.38423	eval-logloss:0.38605
# [35]	train-logloss:0.37635	eval-logloss:0.37832
# [36]	train-logloss:0.37323	eval-logloss:0.37526
# [37]	train-logloss:0.36821	eval-logloss:0.37055
# [38]	train-logloss:0.36450	eval-logloss:0.36682
# [39]	train-logloss:0.36083	eval-logloss:0.36318
# [40]	train-logloss:0.35622	eval-logloss:0.35855
# [41]	train-logloss:0.35077	eval-logloss:0.35315
# [42]	train-logloss:0.34629	eval-logloss:0.34872
# [43]	train-logloss:0.34428	eval-logloss:0.34673
# [44]	train-logloss:0.33989	eval-logloss:0.34243
# [45]	train-logloss:0.33677	eval-logloss:0.33936
# [46]	train-logloss:0.32934	eval-logloss:0.33204
# [47]	train-logloss:0.32612	eval-logloss:0.32889
# [48]	train-logloss:0.32254	eval-logloss:0.32538
# [49]	train-logloss:0.31860	eval-logloss:0.32131
# [50]	train-logloss:0.31347	eval-logloss:0.31597
# [51]	train-logloss:0.30886	eval-logloss:0.31137
# [52]	train-logloss:0.30387	eval-logloss:0.30652
# [53]	train-logloss:0.30039	eval-logloss:0.30321
# [54]	train-logloss:0.29520	eval-logloss:0.29789
# [55]	train-logloss:0.29203	eval-logloss:0.29472
# [56]	train-logloss:0.28823	eval-logloss:0.29099
# [57]	train-logloss:0.28352	eval-logloss:0.28617
# [58]	train-logloss:0.28096	eval-logloss:0.28363
# [59]	train-logloss:0.27750	eval-logloss:0.28029
# [60]	train-logloss:0.27279	eval-logloss:0.27558
# [61]	train-logloss:0.26928	eval-logloss:0.27215
# [62]	train-logloss:0.26678	eval-logloss:0.26972
# [63]	train-logloss:0.26341	eval-logloss:0.26629
# [64]	train-logloss:0.26052	eval-logloss:0.26341
# [65]	train-logloss:0.25795	eval-logloss:0.26070
# [66]	train-logloss:0.25522	eval-logloss:0.25795
# [67]	train-logloss:0.25113	eval-logloss:0.25401
# [68]	train-logloss:0.24732	eval-logloss:0.25028
# [69]	train-logloss:0.24067	eval-logloss:0.24393
# [70]	train-logloss:0.23748	eval-logloss:0.24085
# [71]	train-logloss:0.23367	eval-logloss:0.23698
# [72]	train-logloss:0.22743	eval-logloss:0.23081
# [73]	train-logloss:0.22557	eval-logloss:0.22901
# [74]	train-logloss:0.22338	eval-logloss:0.22684
# [75]	train-logloss:0.21865	eval-logloss:0.22196
# [76]	train-logloss:0.21593	eval-logloss:0.21927
# [77]	train-logloss:0.21212	eval-logloss:0.21547
# [78]	train-logloss:0.20773	eval-logloss:0.21108
# [79]	train-logloss:0.20592	eval-logloss:0.20938
# [80]	train-logloss:0.20448	eval-logloss:0.20793
# [81]	train-logloss:0.20280	eval-logloss:0.20636
# [82]	train-logloss:0.20063	eval-logloss:0.20408
# [83]	train-logloss:0.19880	eval-logloss:0.20225
# [84]	train-logloss:0.19691	eval-logloss:0.20033
# [85]	train-logloss:0.19597	eval-logloss:0.19942
# [86]	train-logloss:0.19395	eval-logloss:0.19743
# [87]	train-logloss:0.19141	eval-logloss:0.19490
# [88]	train-logloss:0.18935	eval-logloss:0.19282
# [89]	train-logloss:0.18660	eval-logloss:0.19008
# [90]	train-logloss:0.18244	eval-logloss:0.18584
# [91]	train-logloss:0.17982	eval-logloss:0.18326
# [92]	train-logloss:0.17799	eval-logloss:0.18143
# [93]	train-logloss:0.17454	eval-logloss:0.17811
# [94]	train-logloss:0.17069	eval-logloss:0.17425
# [95]	train-logloss:0.16777	eval-logloss:0.17133
# [96]	train-logloss:0.16539	eval-logloss:0.16896
# [97]	train-logloss:0.16252	eval-logloss:0.16611
# [98]	train-logloss:0.16086	eval-logloss:0.16446
# [99]	train-logloss:0.15811	eval-logloss:0.16171
# 訓練時間: 60.65121555328369

# %%
# 指定參數
params = {
    'max_depth': 3,  # 決定樹的深度
    'eta': 0.3,      # 學習率
    'objective': 'binary:logistic',
#    'eval_metric': 'logloss' , # logloss作為評估指標,
    'eval_metric': 'auc' , # auc 作為評估指標,
    'scale_pos_weight': scale_pos_weight ,
}

num_round = 100  # 訓練迭代的次數
early_stopping_rounds=50
eval_set = [(dtrain, 'train'), (dtest, 'eval')]

# 訓練模型
start = time.time()
evals_result = {}
bst = xgb.train(params, dtrain, num_round, evals=eval_set, early_stopping_rounds=early_stopping_rounds,evals_result=evals_result)
end = time.time()
print("訓練時間:", end - start)

#import xgboost as xgb
#import matplotlib.pyplot as plt


# 訓練和測試誤差曲線的繪製
train_error = evals_result['train']['auc']  # 換成您的評估指標 logloss or auc
test_error = evals_result['eval']['auc']  # 換成您的評估指標
epochs = len(train_error)
x_axis = range(0, epochs)

# 繪圖
plt.figure(figsize=(12,6))
plt.plot(x_axis, train_error, label='Train')
plt.plot(x_axis, test_error, label='Test')
plt.legend()

plt.ylabel('Error')
plt.xlabel('Number of iterations')
plt.title('XGBoost Train/Test Error over Iterations [AUC]')
plt.show()


plt.figure(figsize=(100, 80))  # 這裡10是寬度, 8是高度, 單位是英寸
#xgb.plot_importance(bst)
xgb.plot_importance(bst, importance_type='weight', max_num_features=30, height=0.5)
plt.rcParams['font.size'] = 8
plt.show()  # 顯示圖形
plt.savefig('feature_importance.jpg', format='jpg', dpi=300, bbox_inches='tight')
plt.close()  # 關閉圖形，避免再次顯示


xgb.to_graphviz(bst)
# Out:
# [0]	train-auc:0.62552	eval-auc:0.50554
# [1]	train-auc:0.69313	eval-auc:0.53796
# [2]	train-auc:0.72534	eval-auc:0.54246
# [3]	train-auc:0.77197	eval-auc:0.53216
# [4]	train-auc:0.81800	eval-auc:0.52984
# [5]	train-auc:0.83743	eval-auc:0.52048
# [6]	train-auc:0.84573	eval-auc:0.52100
# [7]	train-auc:0.85882	eval-auc:0.52149
# [8]	train-auc:0.86803	eval-auc:0.51753
# [9]	train-auc:0.88641	eval-auc:0.52395
# [10]	train-auc:0.89110	eval-auc:0.52076
# [11]	train-auc:0.90294	eval-auc:0.52483
# [12]	train-auc:0.90686	eval-auc:0.52487
# [13]	train-auc:0.90924	eval-auc:0.52305
# [14]	train-auc:0.91264	eval-auc:0.51670
# [15]	train-auc:0.91803	eval-auc:0.51802
# [16]	train-auc:0.92339	eval-auc:0.52170
# [17]	train-auc:0.93229	eval-auc:0.52419
# [18]	train-auc:0.93905	eval-auc:0.51239
# [19]	train-auc:0.94048	eval-auc:0.51579
# [20]	train-auc:0.94521	eval-auc:0.51865
# [21]	train-auc:0.94855	eval-auc:0.51924
# [22]	train-auc:0.95132	eval-auc:0.52287
# [23]	train-auc:0.95303	eval-auc:0.51233
# [24]	train-auc:0.95489	eval-auc:0.51388
# [25]	train-auc:0.95859	eval-auc:0.51686
# [26]	train-auc:0.96275	eval-auc:0.52415
# [27]	train-auc:0.96599	eval-auc:0.53191
# [28]	train-auc:0.96900	eval-auc:0.53769
# [29]	train-auc:0.97113	eval-auc:0.53278
# [30]	train-auc:0.97276	eval-auc:0.53748
# [31]	train-auc:0.97583	eval-auc:0.53313
# [32]	train-auc:0.97718	eval-auc:0.53576
# [33]	train-auc:0.97808	eval-auc:0.53493
# [34]	train-auc:0.97933	eval-auc:0.54010
# [35]	train-auc:0.98130	eval-auc:0.54393
# [36]	train-auc:0.98205	eval-auc:0.54397
# [37]	train-auc:0.98289	eval-auc:0.54467
# [38]	train-auc:0.98372	eval-auc:0.54354
# [39]	train-auc:0.98387	eval-auc:0.54547
# [40]	train-auc:0.98481	eval-auc:0.54262
# [41]	train-auc:0.98642	eval-auc:0.54131
# [42]	train-auc:0.98754	eval-auc:0.54570
# [43]	train-auc:0.98792	eval-auc:0.54660
# [44]	train-auc:0.98872	eval-auc:0.54286
# [45]	train-auc:0.98936	eval-auc:0.54260
# [46]	train-auc:0.99054	eval-auc:0.54768
# [47]	train-auc:0.99085	eval-auc:0.54819
# [48]	train-auc:0.99130	eval-auc:0.54941
# [49]	train-auc:0.99212	eval-auc:0.54723
# [50]	train-auc:0.99279	eval-auc:0.54312
# [51]	train-auc:0.99335	eval-auc:0.54272
# [52]	train-auc:0.99389	eval-auc:0.54064
# [53]	train-auc:0.99421	eval-auc:0.54049
# [54]	train-auc:0.99493	eval-auc:0.54033
# [55]	train-auc:0.99504	eval-auc:0.54187
# [56]	train-auc:0.99522	eval-auc:0.54640
# [57]	train-auc:0.99573	eval-auc:0.54537
# [58]	train-auc:0.99585	eval-auc:0.54385
# [59]	train-auc:0.99603	eval-auc:0.54290
# [60]	train-auc:0.99624	eval-auc:0.54141
# [61]	train-auc:0.99646	eval-auc:0.54057
# [62]	train-auc:0.99664	eval-auc:0.54367
# [63]	train-auc:0.99679	eval-auc:0.54865
# [64]	train-auc:0.99707	eval-auc:0.55126
# [65]	train-auc:0.99738	eval-auc:0.55018
# [66]	train-auc:0.99751	eval-auc:0.55224
# [67]	train-auc:0.99772	eval-auc:0.54685
# [68]	train-auc:0.99787	eval-auc:0.54510
# [69]	train-auc:0.99817	eval-auc:0.54166
# [70]	train-auc:0.99829	eval-auc:0.53784
# [71]	train-auc:0.99848	eval-auc:0.53872
# [72]	train-auc:0.99869	eval-auc:0.54318
# [73]	train-auc:0.99879	eval-auc:0.54585
# [74]	train-auc:0.99886	eval-auc:0.54350
# [75]	train-auc:0.99900	eval-auc:0.54152
# [76]	train-auc:0.99909	eval-auc:0.54025
# [77]	train-auc:0.99917	eval-auc:0.54089
# [78]	train-auc:0.99926	eval-auc:0.53981
# [79]	train-auc:0.99931	eval-auc:0.54211
# [80]	train-auc:0.99935	eval-auc:0.54388
# [81]	train-auc:0.99937	eval-auc:0.54424
# [82]	train-auc:0.99941	eval-auc:0.54516
# [83]	train-auc:0.99943	eval-auc:0.54431
# [84]	train-auc:0.99946	eval-auc:0.54416
# [85]	train-auc:0.99945	eval-auc:0.54577
# [86]	train-auc:0.99949	eval-auc:0.54863
# [87]	train-auc:0.99950	eval-auc:0.54861
# [88]	train-auc:0.99955	eval-auc:0.54814
# [89]	train-auc:0.99961	eval-auc:0.54917
# [90]	train-auc:0.99963	eval-auc:0.55271
# [91]	train-auc:0.99966	eval-auc:0.55205
# [92]	train-auc:0.99966	eval-auc:0.55099
# [93]	train-auc:0.99969	eval-auc:0.54811
# [94]	train-auc:0.99972	eval-auc:0.55007
# [95]	train-auc:0.99974	eval-auc:0.54760
# [96]	train-auc:0.99976	eval-auc:0.54873
# [97]	train-auc:0.99978	eval-auc:0.54626
# [98]	train-auc:0.99978	eval-auc:0.54587
# [99]	train-auc:0.99979	eval-auc:0.54301
# 訓練時間: 52.75180101394653

# %%
plt.figure(figsize=(100, 80))  # 這裡10是寬度, 8是高度, 單位是英寸
#xgb.plot_importance(bst)
xgb.plot_importance(bst, importance_type='weight', max_num_features=30, height=0.5)
plt.rcParams['font.size'] = 8
plt.show()  # 顯示圖形
plt.savefig('feature_importance.jpg', format='jpg', dpi=300, bbox_inches='tight')
plt.close()  # 關閉圖形，避免再次顯示


xgb.to_graphviz(bst)

# %%
# 用測試數據評估模型
preds = bst.predict(dtest)

# %%
# 假设 preds 是模型的预测结果，Y_test 是真实的标签
mse = mean_squared_error(Y_test, preds)
print("Mean Squared Error:", mse)


from sklearn.metrics import roc_auc_score, f1_score

# Make predictions on the test set
y_pred = bst.predict(dtest)
#y_pred_proba = bst.predict_proba(X_test)[:, 1]

# Calculate AUC
#auc = roc_auc_score(Y_test, y_pred_proba)
#print(f"AUC: {auc}")

#  Calculate F1 score
# f1 = f1_score(Y_test, y_pred)
# print(f"F1 Score: {f1}")
from sklearn.metrics import f1_score

# 將連續的目標變量轉換為二進制值
Y_test_binary = np.where(Y_test > 0.5, 1, 0)

# 計算 F1 分數
f1 = f1_score(Y_test_binary, y_pred.round(), average='micro')
print(f"F1 Score: {f1}")
plt.show()
# Out:
# Mean Squared Error: 0.037188997010950256
# F1 Score: 0.9711707498722645

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!cp '/content/data_1440_>0.csv' '/content/drive/MyDrive/Colab Notebooks/副本_share'
# Out:
# ^C
